# %%
# !pip install googlemaps
# Out:
# ...
#   Running setup.py bdist_wheel for googlemaps ... done
#   Stored in directory: /Users/jamesmoulds/Library/Caches/pip/wheels/85/13/9a/6be797f54ea8759a77961114dcbac86fef2a6cc7a4d6ad9785
# Successfully built googlemaps
# notebook 6.0.2 has requirement jupyter-client>=5.3.4, but you'll have jupyter-client 5.3.3 which is incompatible.
# notebook 6.0.2 has requirement jupyter-core>=4.6.0, but you'll have jupyter-core 4.4.0 which is incompatible.
# ...
# You are using pip version 10.0.1, however version 20.1 is available.
# You should consider upgrading via the 'pip install --upgrade pip' command.

# %%
# !pip install prettyprint
# Out:
# ...
#   Running setup.py bdist_wheel for prettyprint ... done
#   Stored in directory: /Users/jamesmoulds/Library/Caches/pip/wheels/9e/79/19/8ef925fdc275044a78b6243438800941e85f8de8c3b7a6bcd1
# Successfully built prettyprint
# notebook 6.0.2 has requirement jupyter-client>=5.3.4, but you'll have jupyter-client 5.3.3 which is incompatible.
# notebook 6.0.2 has requirement jupyter-core>=4.6.0, but you'll have jupyter-core 4.4.0 which is incompatible.
# ...
# You are using pip version 10.0.1, however version 20.1 is available.
# You should consider upgrading via the 'pip install --upgrade pip' command.

# %%
import requests
import json
import time
import googlemaps

# %%
# Define the API key
API_KEY = 'AIzaSyD8pIlC-yZ1aQpfOg2eR3hl02dwXzhkXbE'

# %%
#Define our Client variable
gmaps = googlemaps.Client(key = API_KEY)

# %%
#Define our search
places_result = gmaps.places_nearby(location = "55.956952, -3.186457", radius = 1000, type="restaurant")

# %%
#Pause the script for a few seconds before getting the next results
# time.sleep(3)

# %%
# places_result = gmaps.places_nearby(page_token = places_result['next_page_token'])

# %%
# places_result
# Out:
# {'html_attributions': [],
#  'results': [{'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 55.95745040000001, 'lng': -3.1855506},
#     'viewport': {'northeast': {'lat': 55.9587648302915,
#       'lng': -3.184129669708498},
#      'southwest': {'lat': 55.9560668697085, 'lng': -3.186827630291502}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/restaurant-71.png',
#    'id': '8b0876771ede0eaea6bb0f8a2c7865e37d303a6c',
#    'name': 'Shezan Indian Cuisine',
#    'opening_hours': {'open_now': True},
#    'photos': [{'height': 2268,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/104865422195841551837">Tom Harney</a>'],
#      'photo_reference': 'CmRaAAAAsjNVrQMSP_lVmnTyYBfJS0TUxLtrpPOie4CMMOrXdSyYUXQJ8rGNj7kwlW79-mLqFMcfmV2JGKw_RCROOD_4Dhg9Es-fpf4VMD7jr7ccqb00VRHPT8uS3X923jF4Lkl9EhCPbApJCKxm83EF-FDQQQh7GhQuiW3tJuVy2AGkbL6c1PE0zO9LLw',
#      'width': 4032}],
#    'place_id': 'ChIJb1SXDIzHh0gRf_GaJWM-F0I',
# ...

# %%
import pandas as pd
import pprint

# %%
for place in places_result['results']:
    
    #define my place_id
    my_place_id = place['place_id']
    
    #define the fields we want sent back
    my_fields = ['name', 'rating']
    
    
    #make a request for the details
    place_details = gmaps.place(place_id=my_place_id, fields=my_fields)
    
    pprint.pprint(place_details)
# Out:
# {'html_attributions': [],
#  'result': {'name': 'Jurys Inn Edinburgh', 'rating': 3.8},
#  'status': 'OK'}
# {'html_attributions': [],
#  'result': {'name': 'Le Monde Hotel', 'rating': 4.1},
#  'status': 'OK'}
# {'html_attributions': [],
#  'result': {'name': 'Parliament House Hotel', 'rating': 4.2},
#  'status': 'OK'}
# {'html_attributions': [],
#  'result': {'name': 'The Place Hotel', 'rating': 4.1},
#  'status': 'OK'}
# {'html_attributions': [],
#  'result': {'name': 'No11 Brasserie & Boutique Hotel', 'rating': 4.4},
#  'status': 'OK'}
# ---------------------------------------------------------------------------
# _OverQueryLimit                           Traceback (most recent call last)
# /opt/anaconda3/envs/learn-env/lib/python3.6/site-packages/googlemaps/client.py in _request(self, url, params, first_request_time, retry_counter, base_url, accepts_clientid, extract_body, requests_kwargs, post_json)
#     303             else:
# ...
